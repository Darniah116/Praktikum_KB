# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## File Record Charts.csv

# %%
df = pd.read_csv('Pizza_Restaurants.csv')
df.head()
# Out:
#                      id                                  address  \
# 0  AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 1  AVwc_6KEIN2L1WUfrKAH  Cascade Village Mall Across From Target
# 2  AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 3  AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
# 4  AVwc_6qRByjofQCxkcxw                     148 S Barrington Ave
#
#                        categories         city country  \
# 0                     Pizza Place         Bend      US
# 1                     Pizza Place         Bend      US
# 2  American Restaurant,Bar,Bakery  Los Angeles      US
# 3  American Restaurant,Bar,Bakery  Los Angeles      US
# 4  American Restaurant,Bar,Bakery  Los Angeles      US
#
#                                                 keys   latitude   longitude  \
# 0  us/or/bend/cascadevillagemallacrossfromtarget/...  44.102665 -121.300797
# 1  us/or/bend/cascadevillagemallacrossfromtarget/...  44.102665 -121.300797
# ...

# %% [markdown]
# ## Kunci Dataframe

# %%
df.keys()
# Out:
# Index(['id', 'address', 'categories', 'city', 'country', 'keys', 'latitude',
#        'longitude', 'menuPageURL', 'menus.amountMax', 'menus.amountMin',
#        'menus.currency', 'menus.dateSeen', 'menus.description', 'menus.name',
#        'name', 'postalCode', 'priceRangeCurrency', 'priceRangeMin',
#        'priceRangeMax', 'province'],
#       dtype='object')

# %% [markdown]
# ## Info DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3510 entries, 0 to 3509
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  3510 non-null   object
#  1   address             3510 non-null   object
#  2   categories          3510 non-null   object
#  3   city                3510 non-null   object
#  4   country             3510 non-null   object
#  5   keys                3510 non-null   object
#  6   latitude            3510 non-null   float64
#  7   longitude           3510 non-null   float64
#  8   menuPageURL         610 non-null    object
#  9   menus.amountMax     2948 non-null   float64
#  10  menus.amountMin     2948 non-null   float64
#  11  menus.currency      2951 non-null   object
#  12  menus.dateSeen      3510 non-null   object
#  13  menus.description   1526 non-null   object
#  14  menus.name          3510 non-null   object
# ...

# %% [markdown]
# ## Deskripsi DataFrame

# %%
df.describe()
# Out:
#           latitude    longitude  menus.amountMax  menus.amountMin  \
# count  3510.000000  3510.000000      2948.000000      2948.000000
# mean     38.555114   -87.472055        12.479186        11.427849
# std       4.651092    16.430008        13.398923         7.262919
# min      18.411826  -157.837461         0.000000         0.000000
# 25%      35.769852   -94.202573         7.500000         7.000000
# 50%      40.020710   -81.675414        11.870000        10.990000
# 75%      41.455179   -74.743820        15.950000        14.950000
# max      64.854370   -66.024871       312.950000       118.990000
#
#        priceRangeMin  priceRangeMax
# count    1557.000000    1557.000000
# mean       15.597945      36.566474
# std        18.495854      21.737839
# min         0.000000      12.000000
# 25%         0.000000      30.000000
# 50%        25.000000      40.000000
# 75%        25.000000      40.000000
# max       347.000000     666.000000

# %% [markdown]
# ## Korelasi DataFrame

# %%
df.corr()
# Out:
# C:\Users\Aspire 5\AppData\Local\Temp\ipykernel_18744\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                  latitude  longitude  menus.amountMax  menus.amountMin  \
# latitude         1.000000   0.265316        -0.080418        -0.088359
# longitude        0.265316   1.000000        -0.050653         0.035573
# menus.amountMax -0.080418  -0.050653         1.000000         0.535788
# menus.amountMin -0.088359   0.035573         0.535788         1.000000
# priceRangeMin    0.102451   0.080121         0.054797         0.063362
# priceRangeMax    0.045673   0.036391         0.025957         0.043480
#
#                  priceRangeMin  priceRangeMax
# latitude              0.102451       0.045673
# longitude             0.080121       0.036391
# ...

# %% [markdown]
# ## Grafik Boxplot

# %%
plt.boxplot(df[['latitude','menus.amountMin','priceRangeMin']], labels=['Garis Lintang','menu.jumlahMin','harga.minimal'])
plt.title('GRAFIK BOXPLOT')
plt.xlabel('nilai x')
plt.ylabel('nilai y')
plt.show()

# %% [markdown]
# ## Grafik Heatmap

# %%
sns.heatmap(data=df.corr(), cmap ='Greens')
plt.title('GRAFIK HEATMAP')
plt.xlabel('nilai x')
plt.ylabel('nilai y')
plt.show()
# Out:
# C:\Users\Aspire 5\AppData\Local\Temp\ipykernel_18744\3619253142.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=df.corr(), cmap ='Greens')

# %% [markdown]
# ## Grafik Batang

# %%
df['priceRangeMin'].value_counts().plot.bar()
plt.title('Grafik Batang')
plt.xlabel('nilai x')
plt.ylabel('nilai y')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Diagram Batang')
plt.xlabel('nilai x')
plt.ylabel('nilai y')
plt.hist(df['priceRangeMin'], label ='Harga.minimal')
plt.hist(df['menus.amountMax'], label ='menu.jumlahMin')
plt.legend()
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# ## Grafik Pie

# %%
plt.figure(figsize=(10,5))
plt.title('DIAGRAM PIE')
plt.pie(df['priceRangeMin'].value_counts(), labels=['25','50','0','31','7','10','164','347'], startangle=90, autopct='%.1f%%', explode=(0.10,0.10,0.10,0.10,0.10,0.10,0.10,0.10))
plt.show()

# %%
df.tail(50)
# Out:
#                         id                              address  \
# 3460  AVweT3Ur_7pvs4fzB3jP                       157 S Weber Rd
# 3461  AVweT3Ur_7pvs4fzB3jP                       157 S Weber Rd
# 3462  AVweT3Ur_7pvs4fzB3jP                       157 S Weber Rd
# 3463  AVweT3Ur_7pvs4fzB3jP                       157 S Weber Rd
# 3464  AVweT3Ur_7pvs4fzB3jP                       157 S Weber Rd
# 3465  AVweT3Ur_7pvs4fzB3jP                       157 S Weber Rd
# 3466  AVweT3Ur_7pvs4fzB3jP                       157 S Weber Rd
# 3467  AVweT3Ur_7pvs4fzB3jP                       157 S Weber Rd
# 3468  AVweT3Ur_7pvs4fzB3jP                       157 S Weber Rd
# 3469  AVweTiNckufWRAb5BxSk                    1016 S College Rd
# 3470  AVweTiNckufWRAb5BxSk                    1016 S College Rd
# 3471  AVweTKY6kufWRAb5BuJ4                    888 Union Mill Rd
# 3472  AVweTZpH_7pvs4fzBz2d                      2620 E Third St
# 3473  AVweTZpH_7pvs4fzBz2d                      2620 E Third St
# ...

# %% [markdown]
# ## Grafik Plot & Garis

# %%
plt.figure(figsize=(15,15))
plt.title('Diagram Scatter')
plt.scatter(df['menus.dateSeen'],df['priceRangeMax'], label='HargaMaksimal')
plt.xticks(rotation=90)
plt.xlabel('Tahun')
plt.ylabel('HargaMaksimal')
plt.legend()
plt.show()
